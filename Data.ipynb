# %% [markdown]
# # Data

# %%
# Data manipulation libs #
import numpy as np
import pandas as pd

# %%
# visulization libs #
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
stack_overflow_18 = pd.read_csv("survey_results_public.csv")
stack_overflow_18.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Respondent Hobby OpenSource         Country         Student  \
# 0           1   Yes         No           Kenya              No
# 1           3   Yes        Yes  United Kingdom              No
# 2           4   Yes        Yes   United States              No
# 3           5    No         No   United States              No
# 4           7   Yes         No    South Africa  Yes, part-time
#
#            Employment                                    FormalEducation  \
# 0  Employed part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2  Employed full-time                                   Associate degree
# 3  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4  Employed full-time  Some college/university study without earning ...
#
#                                       UndergradMajor  \
# 0                          Mathematics or statistics
# 1  A natural science (ex. biology, chemistry, phy...
# 2  Computer science, computer engineering, or sof...
# 3  Computer science, computer engineering, or sof...
# 4  Computer science, computer engineering, or sof...
#
#                 CompanySize  \
# 0        20 to 99 employees
# 1  10,000 or more employees
# 2        20 to 99 employees
# 3      100 to 499 employees
# 4  10,000 or more employees
#
#                                              DevType  ...  \
# 0                               Full-stack developer  ...
# 1  Database administrator;DevOps specialist;Full-...  ...
# 2           Engineering manager;Full-stack developer  ...
# 3                               Full-stack developer  ...
# 4  Data or business analyst;Desktop or enterprise...  ...
#
#                      Exercise Gender         SexualOrientation  \
# 0        3 - 4 times per week   Male  Straight or heterosexual
# 1   Daily or almost every day   Male  Straight or heterosexual
# 2                         NaN    NaN                       NaN
# 3  I don't typically exercise   Male  Straight or heterosexual
# 4        3 - 4 times per week   Male  Straight or heterosexual
#
#                                     EducationParents  \
# 0           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2                                                NaN
# 3  Some college/university study without earning ...
# 4  Some college/university study without earning ...
#
#                   RaceEthnicity                Age Dependents  MilitaryUS  \
# 0   Black or of African descent  25 - 34 years old        Yes         NaN
# 1  White or of European descent  35 - 44 years old        Yes         NaN
# 2                           NaN                NaN        NaN         NaN
# 3  White or of European descent  35 - 44 years old         No          No
# 4  White or of European descent  18 - 24 years old        Yes         NaN
#
#                           SurveyTooLong     SurveyEasy
# 0  The survey was an appropriate length      Very easy
# 1  The survey was an appropriate length  Somewhat easy
# 2                                   NaN            NaN
# 3  The survey was an appropriate length  Somewhat easy
# 4  The survey was an appropriate length  Somewhat easy
#
# [5 rows x 129 columns]

# %%
# List of columns we are interested in for salary analysis #
salaries_cols = ["Country","Student","Employment","FormalEducation","UndergradMajor","CompanySize","DevType","YearsCoding","YearsCodingProf","EducationTypes","SelfTaughtTypes","LanguageWorkedWith","Salary","LanguageDesireNextYear","FrameworkWorkedWith","FrameworkDesireNextYear","OperatingSystem","Age","ConvertedSalary"]

# %%
salaries = stack_overflow_18[salaries_cols]
salaries.head()
# Out:
#           Country         Student          Employment  \
# 0           Kenya              No  Employed part-time
# 1  United Kingdom              No  Employed full-time
# 2   United States              No  Employed full-time
# 3   United States              No  Employed full-time
# 4    South Africa  Yes, part-time  Employed full-time
#
#                                      FormalEducation  \
# 0           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2                                   Associate degree
# 3           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4  Some college/university study without earning ...
#
#                                       UndergradMajor  \
# 0                          Mathematics or statistics
# 1  A natural science (ex. biology, chemistry, phy...
# 2  Computer science, computer engineering, or sof...
# 3  Computer science, computer engineering, or sof...
# 4  Computer science, computer engineering, or sof...
#
#                 CompanySize  \
# 0        20 to 99 employees
# 1  10,000 or more employees
# 2        20 to 99 employees
# 3      100 to 499 employees
# 4  10,000 or more employees
#
#                                              DevType       YearsCoding  \
# 0                               Full-stack developer         3-5 years
# 1  Database administrator;DevOps specialist;Full-...  30 or more years
# 2           Engineering manager;Full-stack developer       24-26 years
# 3                               Full-stack developer       18-20 years
# 4  Data or business analyst;Desktop or enterprise...         6-8 years
#
#   YearsCodingProf                                     EducationTypes  \
# 0       3-5 years  Taught yourself a new language, framework, or ...
# 1     18-20 years  Taught yourself a new language, framework, or ...
# 2       6-8 years                                                NaN
# 3     12-14 years  Completed an industry certification program (e...
# 4       0-2 years  Taken a part-time in-person course in programm...
#
#                                      SelfTaughtTypes  \
# 0  The official documentation and/or standards fo...
# 1  The official documentation and/or standards fo...
# 2                                                NaN
# 3  The official documentation and/or standards fo...
# 4  The official documentation and/or standards fo...
#
#                                  LanguageWorkedWith  Salary  \
# 0                        JavaScript;Python;HTML;CSS     NaN
# 1                      JavaScript;Python;Bash/Shell   51000
# 2                                               NaN     NaN
# 3  C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell     NaN
# 4                C;C++;Java;Matlab;R;SQL;Bash/Shell  260000
#
#                              LanguageDesireNextYear FrameworkWorkedWith  \
# 0                        JavaScript;Python;HTML;CSS        Django;React
# 1                                         Go;Python              Django
# 2                                               NaN                 NaN
# 3  C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell                 NaN
# 4              Assembly;C;C++;Matlab;SQL;Bash/Shell                 NaN
#
#    FrameworkDesireNextYear OperatingSystem                Age  ConvertedSalary
# 0             Django;React     Linux-based  25 - 34 years old              NaN
# 1                    React     Linux-based  35 - 44 years old          70841.0
# 2                      NaN             NaN                NaN              NaN
# 3  Angular;.NET Core;React         Windows  35 - 44 years old              NaN
# 4                      NaN         Windows  18 - 24 years old          21426.0

# %%
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98855 entries, 0 to 98854
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  98443 non-null  object
#  1   Student                  94901 non-null  object
#  2   Employment               95321 non-null  object
#  3   FormalEducation          94703 non-null  object
#  4   UndergradMajor           79036 non-null  object
#  5   CompanySize              71531 non-null  object
#  6   DevType                  92098 non-null  object
#  7   YearsCoding              93835 non-null  object
#  8   YearsCodingProf          77903 non-null  object
#  9   EducationTypes           67960 non-null  object
#  10  SelfTaughtTypes          57354 non-null  object
#  11  LanguageWorkedWith       78334 non-null  object
#  12  Salary                   50578 non-null  object
#  13  LanguageDesireNextYear   73244 non-null  object
#  14  FrameworkWorkedWith      51620 non-null  object
#  15  FrameworkDesireNextYear  55218 non-null  object
#  16  OperatingSystem          76179 non-null  object
#  17  Age                      64574 non-null  object
#  18  ConvertedSalary          47702 non-null  float64
# dtypes: float64(1), object(18)
# memory usage: 14.3+ MB

# %%
salaries.loc[0:15,:]
# Out:
#            Country         Student          Employment  \
# 0            Kenya              No  Employed part-time
# 1   United Kingdom              No  Employed full-time
# 2    United States              No  Employed full-time
# 3    United States              No  Employed full-time
# 4     South Africa  Yes, part-time  Employed full-time
# 5   United Kingdom              No  Employed full-time
# 6    United States              No  Employed full-time
# 7          Nigeria              No  Employed full-time
# 8    United States              No  Employed full-time
# 9            India              No  Employed full-time
# 10           Spain              No  Employed full-time
# 11           India              No  Employed full-time
# 12         Croatia             NaN  Employed full-time
# 13           India              No  Employed full-time
# 14     Netherlands  Yes, full-time  Employed full-time
# 15          Israel              No  Employed full-time
#
#                                       FormalEducation  \
# 0            Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1            Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2                                    Associate degree
# 3            Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4   Some college/university study without earning ...
# 5            Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6   Some college/university study without earning ...
# 7            Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8   Some college/university study without earning ...
# 9            Bachelor’s degree (BA, BS, B.Eng., etc.)
# 10        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 11           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 12  Some college/university study without earning ...
# 13           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 14  Secondary school (e.g. American high school, G...
# 15        Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                        UndergradMajor  \
# 0                           Mathematics or statistics
# 1   A natural science (ex. biology, chemistry, phy...
# 2   Computer science, computer engineering, or sof...
# 3   Computer science, computer engineering, or sof...
# 4   Computer science, computer engineering, or sof...
# 5   Computer science, computer engineering, or sof...
# 6   Computer science, computer engineering, or sof...
# 7   Computer science, computer engineering, or sof...
# 8   Fine arts or performing arts (ex. graphic desi...
# 9   Computer science, computer engineering, or sof...
# 10  Information systems, information technology, o...
# 11  Another engineering discipline (ex. civil, ele...
# 12  Computer science, computer engineering, or sof...
# 13  Another engineering discipline (ex. civil, ele...
# 14                                                NaN
# 15  Fine arts or performing arts (ex. graphic desi...
#
#                  CompanySize  \
# 0         20 to 99 employees
# 1   10,000 or more employees
# 2         20 to 99 employees
# 3       100 to 499 employees
# 4   10,000 or more employees
# 5         10 to 19 employees
# 6   10,000 or more employees
# 7         10 to 19 employees
# 8       100 to 499 employees
# 9       500 to 999 employees
# 10  1,000 to 4,999 employees
# 11      100 to 499 employees
# 12        20 to 99 employees
# 13        20 to 99 employees
# 14        20 to 99 employees
# 15  5,000 to 9,999 employees
#
#                                               DevType       YearsCoding  \
# 0                                Full-stack developer         3-5 years
# 1   Database administrator;DevOps specialist;Full-...  30 or more years
# 2            Engineering manager;Full-stack developer       24-26 years
# 3                                Full-stack developer       18-20 years
# 4   Data or business analyst;Desktop or enterprise...         6-8 years
# 5   Back-end developer;Database administrator;Fron...         6-8 years
# 6   Back-end developer;Front-end developer;Full-st...        9-11 years
# 7   Designer;Front-end developer;QA or test developer         0-2 years
# 8   Back-end developer;C-suite executive (CEO, CTO...  30 or more years
# 9                                            Designer         0-2 years
# 10  Back-end developer;Database administrator;Mobi...         6-8 years
# 11  Back-end developer;Front-end developer;Full-st...         0-2 years
# 12             Back-end developer;Front-end developer         0-2 years
# 13            Back-end developer;Full-stack developer         3-5 years
# 14     Back-end developer;Front-end developer;Student         0-2 years
# 15                               Full-stack developer         3-5 years
#
#    YearsCodingProf                                     EducationTypes  \
# 0        3-5 years  Taught yourself a new language, framework, or ...
# 1      18-20 years  Taught yourself a new language, framework, or ...
# 2        6-8 years                                                NaN
# 3      12-14 years  Completed an industry certification program (e...
# 4        0-2 years  Taken a part-time in-person course in programm...
# 5        3-5 years  Received on-the-job training in software devel...
# 6        0-2 years  Received on-the-job training in software devel...
# 7        3-5 years  Taken an online course in programming or softw...
# 8      21-23 years  Taken an online course in programming or softw...
# 9              NaN                                                NaN
# 10       0-2 years                                                NaN
# 11             NaN                                                NaN
# 12             NaN                                                NaN
# 13       3-5 years                                                NaN
# 14       0-2 years  Received on-the-job training in software devel...
# 15       3-5 years                                                NaN
#
#                                       SelfTaughtTypes  \
# 0   The official documentation and/or standards fo...
# 1   The official documentation and/or standards fo...
# 2                                                 NaN
# 3   The official documentation and/or standards fo...
# 4   The official documentation and/or standards fo...
# 5   The official documentation and/or standards fo...
# 6   The official documentation and/or standards fo...
# 7                                                 NaN
# 8   The official documentation and/or standards fo...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                                    LanguageWorkedWith  Salary  \
# 0                          JavaScript;Python;HTML;CSS     NaN
# 1                        JavaScript;Python;Bash/Shell   51000
# 2                                                 NaN     NaN
# 3    C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell     NaN
# 4                  C;C++;Java;Matlab;R;SQL;Bash/Shell  260000
# 5          Java;JavaScript;Python;TypeScript;HTML;CSS   30000
# 6                                 JavaScript;HTML;CSS  120000
# 7                      JavaScript;TypeScript;HTML;CSS     NaN
# 8   Assembly;CoffeeScript;Erlang;Go;JavaScript;Lua...  250000
# 9                                                 NaN     NaN
# 10                                                NaN     NaN
# 11                                                NaN     NaN
# 12                                                NaN     NaN
# 13                                               Java     NaN
# 14                Java;JavaScript;PHP;VB.NET;HTML;CSS       0
# 15                                                NaN     NaN
#
#                                LanguageDesireNextYear  \
# 0                          JavaScript;Python;HTML;CSS
# 1                                           Go;Python
# 2                                                 NaN
# 3    C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 4                Assembly;C;C++;Matlab;SQL;Bash/Shell
# 5   C#;Go;Java;JavaScript;Python;SQL;TypeScript;HT...
# 6                     C;Go;JavaScript;Python;HTML;CSS
# 7                        Matlab;SQL;Kotlin;Bash/Shell
# 8                           Erlang;Go;Python;Rust;SQL
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                        Java;Python
# 14                                                NaN
# 15                                                NaN
#
#            FrameworkWorkedWith  FrameworkDesireNextYear OperatingSystem  \
# 0                 Django;React             Django;React     Linux-based
# 1                       Django                    React     Linux-based
# 2                          NaN                      NaN             NaN
# 3                          NaN  Angular;.NET Core;React         Windows
# 4                          NaN                      NaN         Windows
# 5              Angular;Node.js                  Node.js     Linux-based
# 6                Node.js;React         React;TensorFlow           MacOS
# 7              Angular;Node.js         .NET Core;Django         Windows
# 8   Hadoop;Node.js;React;Spark                      NaN           MacOS
# 9                          NaN                      NaN             NaN
# 10                         NaN                      NaN             NaN
# 11                         NaN                      NaN             NaN
# 12                         NaN                      NaN             NaN
# 13                      Spring      Hadoop;Spark;Spring     Linux-based
# 14                         NaN                      NaN         Windows
# 15                         NaN                      NaN             NaN
#
#                   Age  ConvertedSalary
# 0   25 - 34 years old              NaN
# 1   35 - 44 years old          70841.0
# 2                 NaN              NaN
# 3   35 - 44 years old              NaN
# 4   18 - 24 years old          21426.0
# 5   18 - 24 years old          41671.0
# 6   18 - 24 years old         120000.0
# 7   25 - 34 years old              NaN
# 8   35 - 44 years old         250000.0
# 9                 NaN              NaN
# 10                NaN              NaN
# 11                NaN              NaN
# 12                NaN              NaN
# 13                NaN              NaN
# 14  18 - 24 years old              0.0
# 15                NaN              NaN

# %%
# entries for test set #
test_rand = np.random.randint(0,98854,200)
test_rand
# Out:
# array([ 3044, 80440,  6206, 92942, 82217, 32168, 79618, 47554, 54183,
#        19291, 50278, 80015, 37223, 11623, 77702, 57785, 58025, 57574,
#        65023, 74713, 57996, 67000, 25088, 62337, 23899, 77563, 91949,
#         7331, 46083, 61568, 86764, 24801, 63589, 90007, 96838, 44636,
#        51200, 91870, 46096, 14207, 84541, 85553, 33699, 74868, 21594,
#        61449, 39191, 95875,  6332, 67455, 11219, 97147, 63632, 89054,
#        33532, 80722, 21074, 86098, 83107,  2407, 53856, 83151, 41436,
#        30500, 58931, 36328, 39705, 89285, 10595,  2924, 21427, 98738,
#        24978, 36779, 40687, 37374, 37168, 44122, 29886,  1063, 64900,
#        56728, 73128, 85338, 25134, 17990, 29779, 90982, 80584, 21562,
#        27293, 46007, 35764, 12519, 75312, 98486, 75938, 41538, 10217,
#        13207, 79467, 41652, 23409, 45409, 91125, 42510, 53414, 41492,
#        45219, 14545, 29017, 45428, 46942, 45401, 81569, 62018, 13951,
#        49193, 61170, 93933, 94846, 26272,  7823, 49724, 41248, 38953,
#        65965, 51104, 98254, 90354, 22708, 10667, 46002, 73547, 90976,
#        63431, 35516,  3190, 15893, 84249, 61748, 24279, 23545, 18940,
#        96424, 96714, 81802,   113, 13940, 39717, 90525, 50255, 69009,
#        55468, 50464, 33886,  7327, 40942, 48012, 79852, 66475, 59551,
#        18687, 32929, 55892, 83268, 87411, 88226, 35741, 86444, 25371,
#        36615, 37898,  3679, 36640, 24285, 21333, 56757, 67390,  4710,
#        32509, 87408, 61841, 45216, 19143, 30068, 68410,  8491,  2836,
#        63811, 89395, 15121, 10928, 61967, 88415, 80762,    89,  4593,
#        40545, 53034])

# %%
# entries for train set #
train_rand = np.random.randint(0,98854,200)
train_rand
# Out:
# array([17522, 83134,   858, 53284, 37884, 55404, 84157, 47986, 12790,
#        23858, 74174, 73799, 73221, 51125, 36660,  2892, 85790, 12382,
#        83540, 45040, 88759, 10240, 49932, 55602, 43215, 79633, 40143,
#        17485, 90487, 50202, 12068, 62510, 81275, 11215, 60681, 59726,
#        10445, 56746, 94719, 66426,   148, 45875, 37998, 84805, 10275,
#         6992, 27870, 19630,  7715, 45549, 60042, 23568, 59866,  3374,
#        75750, 83779, 74791, 90391, 92415, 77372, 72822,  3773, 91360,
#        82394, 26658, 51201, 89600, 63878, 23963, 80245, 48200, 85722,
#        41987, 30727, 51232, 61086, 69181,   483,  3220, 98566, 78943,
#        83356, 32153, 76857, 30114, 70861,  4957, 64583,  4290, 79449,
#        48565, 75356, 89483, 50280, 14320, 97961, 15270, 83373, 65673,
#        67297, 40468, 12796, 58619, 63346, 27650, 35568, 29819, 94539,
#        34856, 55352, 13480, 47656, 22564, 58819, 92735, 89204, 80122,
#        67133, 41601, 11409, 52292, 47831, 40457, 36993, 85237, 88633,
#        58796, 45024, 26981, 24807, 62686, 93561, 70719, 86294, 96797,
#        30850,  9307, 69938,  6983, 73361,   241, 12634,   708,  8821,
#        74961, 14333, 54481, 35135, 80483, 82638, 36441, 51101, 16930,
#        71255, 17218, 49159, 94604, 63938, 93395, 16961,  5955, 64712,
#        75921, 95055,  4833, 28239, 35892, 54247, 95948, 35426, 61066,
#        52238, 91167, 28864, 72885, 84640, 85062, 25496, 41475, 48798,
#        33077, 24145, 66276, 85191, 91460, 91196, 89245, 61680, 69398,
#        88937, 67003, 52382, 32023,  4646, 80790, 66972, 76366, 69745,
#          634, 87040])

# %%
train_rand/test_rand
# Out:
# array([5.75624179e+00, 1.03349080e+00, 1.38253303e-01, 5.73303781e-01,
#        4.60780617e-01, 1.72233275e+00, 1.05700972e+00, 1.00908441e+00,
#        2.36051898e-01, 1.23674252e+00, 1.47527746e+00, 9.22314566e-01,
#        1.96709024e+00, 4.39860621e+00, 4.71802528e-01, 5.00475902e-02,
#        1.47850065e+00, 2.15062355e-01, 1.28477616e+00, 6.02840202e-01,
#        1.53043313e+00, 1.52835821e-01, 1.99027423e+00, 8.91958227e-01,
#        1.80823465e+00, 1.02668798e+00, 4.36578973e-01, 2.38507707e+00,
#        1.96356574e+00, 8.15391112e-01, 1.39089945e-01, 2.52046288e+00,
#        1.27812987e+00, 1.24601420e-01, 6.26623846e-01, 1.33806793e+00,
#        2.04003906e-01, 6.17677152e-01, 2.05482037e+00, 4.67558246e+00,
#        1.75062987e-03, 5.36217316e-01, 1.12757055e+00, 1.13272693e+00,
#        4.75826619e-01, 1.13785416e-01, 7.11132658e-01, 2.04745763e-01,
#        1.21841440e+00, 6.75250167e-01, 5.35181389e+00, 2.42601418e-01,
#        9.40815942e-01, 3.78871247e-02, 2.25903614e+00, 1.03787072e+00,
#        3.54897030e+00, 1.04986179e+00, 1.11200019e+00, 3.21445783e+01,
#        1.35216132e+00, 4.53752811e-02, 2.20484603e+00, 2.70144262e+00,
#        4.52359539e-01, 1.40940872e+00, 2.25664274e+00, 7.15439324e-01,
#        2.26172723e+00, 2.74435705e+01, 2.24949830e+00, 8.68176386e-01,
#        1.68095924e+00, 8.35449577e-01, 1.25917369e+00, 1.63445176e+00,
#        1.86130542e+00, 1.09469199e-02, 1.07742756e-01, 9.27243650e+01,
#        1.21637904e+00, 1.46939783e+00, 4.39681107e-01, 9.00618716e-01,
#        1.19813798e+00, 3.93891051e+00, 1.66459586e-01, 7.09843705e-01,
#        5.32363745e-02, 3.68467675e+00, 1.77939398e+00, 1.63792466e+00,
#        2.50204116e+00, 4.01629523e+00, 1.90142341e-01, 9.94669293e-01,
#        2.01085096e-01, 2.00715008e+00, 6.42781638e+00, 5.09555539e+00,
#        5.09242830e-01, 3.07212139e-01, 2.50412235e+00, 1.39500980e+00,
#        3.03429355e-01, 8.36697248e-01, 5.58261879e-01, 2.27848742e+00,
#        7.70826423e-01, 3.80556892e+00, 4.64555261e-01, 1.04904464e+00,
#        4.80678284e-01, 1.29554415e+00, 1.13689024e+00, 1.43835661e+00,
#        5.74310085e+00, 1.36468603e+00, 6.80088279e-01, 1.21458912e-01,
#        5.51335850e-01, 1.82060749e+00, 5.17154544e+00, 7.43966696e-01,
#        2.06645171e+00, 2.27538315e+00, 8.91321155e-01, 8.81026925e-01,
#        2.74604596e-01, 2.74553423e-01, 2.76052493e+00, 8.77106965e+00,
#        1.53730273e+00, 1.17331774e+00, 1.06398391e+00, 4.86355252e-01,
#        2.62050907e-01, 2.19241379e+01, 4.39375826e-01, 8.70764045e-01,
#        3.90296042e-03, 5.20367396e-01, 3.00700786e-02, 4.65733897e-01,
#        7.77410188e-01, 1.48199847e-01, 6.66010611e-01, 3.10929204e+02,
#        5.77352941e+00, 2.08067075e+00, 4.02551781e-01, 1.01683415e+00,
#        2.45330319e-01, 1.28461455e+00, 3.41193722e-01, 1.45071711e+00,
#        1.29116965e+01, 1.56167261e+00, 1.94524286e+00, 2.12405450e-01,
#        8.95825498e-02, 1.08666521e+00, 4.06277091e+00, 2.88666525e+00,
#        8.64703356e-02, 3.39133881e-01, 4.10611937e-01, 6.14864099e-01,
#        2.68453597e+00, 4.09814446e-01, 2.40692129e+00, 1.42668305e+00,
#        2.40558869e+00, 7.84561022e+00, 1.98921943e+00, 3.48527898e+00,
#        3.98734355e+00, 4.49213313e-01, 6.15447396e-01, 1.03605096e+01,
#        1.01747208e+00, 2.76233297e-01, 1.07171618e+00, 1.88408970e+00,
#        4.77772554e+00, 3.03299189e+00, 1.30456074e+00, 7.26416205e+00,
#        2.44703808e+01, 1.39375656e+00, 7.49516192e-01, 3.46418888e+00,
#        2.93036237e+00, 7.49753901e-02, 9.13758978e-01, 8.29251381e-01,
#        8.58044944e+02, 1.51850642e+01, 1.56369466e-02, 1.64121130e+00])

# %%
salaries_test = salaries.loc[test_rand,:]
salaries_test.head()
# Out:
#              Country         Student  \
# 3044           India              No
# 80440      Australia              No
# 6206           India  Yes, full-time
# 92942         France  Yes, full-time
# 82217  United States              No
#
#                                               Employment  \
# 3044                                  Employed full-time
# 80440  Independent contractor, freelancer, or self-em...
# 6206                                  Employed full-time
# 92942  Independent contractor, freelancer, or self-em...
# 82217                 Not employed, but looking for work
#
#                                          FormalEducation  \
# 3044            Bachelor’s degree (BA, BS, B.Eng., etc.)
# 80440  Secondary school (e.g. American high school, G...
# 6206            Bachelor’s degree (BA, BS, B.Eng., etc.)
# 92942           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 82217  Secondary school (e.g. American high school, G...
#
#                                           UndergradMajor  \
# 3044                                                 NaN
# 80440                                                NaN
# 6206   Computer science, computer engineering, or sof...
# 92942  A business discipline (ex. accounting, finance...
# 82217                                                NaN
#
#                     CompanySize  \
# 3044   10,000 or more employees
# 80440                       NaN
# 6206   10,000 or more employees
# 92942                       NaN
# 82217                       NaN
#
#                                                  DevType       YearsCoding  \
# 3044   Back-end developer;Front-end developer;Full-st...        9-11 years
# 80440  Back-end developer;Database administrator;Desk...  30 or more years
# 6206             Back-end developer;QA or test developer         3-5 years
# 92942        Back-end developer;Mobile developer;Student         3-5 years
# 82217  Back-end developer;Database administrator;Desi...         3-5 years
#
#       YearsCodingProf                                     EducationTypes  \
# 3044        6-8 years  Taken an online course in programming or softw...
# 80440     27-29 years  Received on-the-job training in software devel...
# 6206        0-2 years  Taken a part-time in-person course in programm...
# 92942             NaN                                                NaN
# 82217       0-2 years  Taken an online course in programming or softw...
#
#                                          SelfTaughtTypes  \
# 3044   The official documentation and/or standards fo...
# 80440  The official documentation and/or standards fo...
# 6206                                                 NaN
# 92942                                                NaN
# 82217  The official documentation and/or standards fo...
#
#                                     LanguageWorkedWith  Salary  \
# 3044    Groovy;Java;JavaScript;SQL;TypeScript;HTML;CSS     NaN
# 80440            C;C#;JavaScript;R;SQL;VB.NET;HTML;CSS   80000
# 6206      C;C++;C#;Groovy;Java;JavaScript;SQL;HTML;CSS  360000
# 92942                                              NaN     NaN
# 82217  C;JavaScript;PHP;Python;SQL;HTML;CSS;Bash/Shell       0
#
#                                   LanguageDesireNextYear  \
# 3044                        Go;R;SQL;TypeScript;HTML;CSS
# 80440                                  C;C#;R;SQL;VB.NET
# 6206                                 Perl;R;Scala;Kotlin
# 92942                                                NaN
# 82217  C;C++;C#;Go;Java;JavaScript;Perl;PHP;Python;Ru...
#
#           FrameworkWorkedWith           FrameworkDesireNextYear  \
# 3044   Angular;Node.js;Spring  Angular;Node.js;React;TensorFlow
# 80440                     NaN                               NaN
# 6206         .NET Core;Spring              Hadoop;Spark;Xamarin
# 92942                     NaN                               NaN
# 82217   Angular;Node.js;React           Angular;.NET Core;React
#
#       OperatingSystem                 Age  ConvertedSalary
# 3044          Windows   25 - 34 years old              NaN
# 80440         Windows   45 - 54 years old          63979.0
# 6206          Windows   18 - 24 years old          67632.0
# 92942             NaN                 NaN              NaN
# 82217             NaN  Under 18 years old              0.0

# %%
salaries_train = salaries.loc[train_rand,:]
salaries_train.head()
# Out:
#               Country         Student                          Employment  \
# 17522          Greece              No                  Employed full-time
# 83134           Nepal  Yes, full-time  Not employed, but looking for work
# 858        Bangladesh              No                  Employed full-time
# 53284           India  Yes, full-time                  Employed full-time
# 37884  Czech Republic              No                  Employed part-time
#
#                                    FormalEducation  \
# 17522     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 83134     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 858    Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 53284     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 37884                    Primary/elementary school
#
#                                           UndergradMajor  \
# 17522  Computer science, computer engineering, or sof...
# 83134                      Web development or web design
# 858    Computer science, computer engineering, or sof...
# 53284  Computer science, computer engineering, or sof...
# 37884                                                NaN
#
#                    CompanySize  \
# 17522  Fewer than 10 employees
# 83134                      NaN
# 858         10 to 19 employees
# 53284  Fewer than 10 employees
# 37884     100 to 499 employees
#
#                                                  DevType YearsCoding  \
# 17522  Back-end developer;Data or business analyst;Da...   3-5 years
# 83134           Front-end developer;Full-stack developer   3-5 years
# 858    Back-end developer;Desktop or enterprise appli...   6-8 years
# 53284                Back-end developer;Designer;Student   3-5 years
# 37884  Back-end developer;Desktop or enterprise appli...   3-5 years
#
#       YearsCodingProf                                     EducationTypes  \
# 17522       0-2 years  Taught yourself a new language, framework, or ...
# 83134       0-2 years  Participated in a full-time developer training...
# 858         6-8 years  Taken an online course in programming or softw...
# 53284             NaN                                                NaN
# 37884       0-2 years  Received on-the-job training in software devel...
#
#                                          SelfTaughtTypes  \
# 17522  The official documentation and/or standards fo...
# 83134                                                NaN
# 858                                                  NaN
# 53284                                                NaN
# 37884  The official documentation and/or standards fo...
#
#                                       LanguageWorkedWith  Salary  \
# 17522                 C#;Java;Matlab;Python;SQL;HTML;CSS     510
# 83134                              JavaScript;TypeScript     120
# 858    C++;C#;Java;JavaScript;Matlab;SQL;HTML;Bash/Shell  100000
# 53284                                         C;PHP;HTML     NaN
# 37884  C;C++;C#;Java;JavaScript;Lua;PHP;Python;SQL;HT...     220
#
#                                   LanguageDesireNextYear  \
# 17522  C++;C#;Java;JavaScript;Objective-C;Perl;Python...
# 83134                              JavaScript;TypeScript
# 858                                                  NaN
# 53284                                           Python;R
# 37884  Assembly;C++;C#;Perl;Python;R;Ruby;Rust;Bash/S...
#
#                       FrameworkWorkedWith  \
# 17522                               Spark
# 83134               Angular;Node.js;React
# 858                               Angular
# 53284                                 NaN
# 37884  .NET Core;TensorFlow;Torch/PyTorch
#
#                                  FrameworkDesireNextYear OperatingSystem  \
# 17522  Angular;Django;Hadoop;Node.js;Spark;Spring;Ten...     Linux-based
# 83134                              Angular;Node.js;React         Windows
# 858                                                  NaN           MacOS
# 53284                                                NaN             NaN
# 37884                               .NET Core;TensorFlow     Linux-based
#
#                       Age  ConvertedSalary
# 17522   18 - 24 years old              NaN
# 83134   18 - 24 years old           1440.0
# 858     25 - 34 years old          14436.0
# 53284                 NaN              NaN
# 37884  Under 18 years old           3228.0

# %%
# saving the dataframe #
salaries_test.to_csv('salaries_test.csv')
salaries_train.to_csv('salaries_train.csv')

# %%
# uploading train dataframe #
# salaries_train = pd.read_csv("salaries_train.csv")

# %%
salaries_train.head()
# Out:
#               Country         Student                          Employment  \
# 17522          Greece              No                  Employed full-time
# 83134           Nepal  Yes, full-time  Not employed, but looking for work
# 858        Bangladesh              No                  Employed full-time
# 53284           India  Yes, full-time                  Employed full-time
# 37884  Czech Republic              No                  Employed part-time
#
#                                    FormalEducation  \
# 17522     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 83134     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 858    Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 53284     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 37884                    Primary/elementary school
#
#                                           UndergradMajor  \
# 17522  Computer science, computer engineering, or sof...
# 83134                      Web development or web design
# 858    Computer science, computer engineering, or sof...
# 53284  Computer science, computer engineering, or sof...
# 37884                                                NaN
#
#                    CompanySize  \
# 17522  Fewer than 10 employees
# 83134                      NaN
# 858         10 to 19 employees
# 53284  Fewer than 10 employees
# 37884     100 to 499 employees
#
#                                                  DevType YearsCoding  \
# 17522  Back-end developer;Data or business analyst;Da...   3-5 years
# 83134           Front-end developer;Full-stack developer   3-5 years
# 858    Back-end developer;Desktop or enterprise appli...   6-8 years
# 53284                Back-end developer;Designer;Student   3-5 years
# 37884  Back-end developer;Desktop or enterprise appli...   3-5 years
#
#       YearsCodingProf                                     EducationTypes  \
# 17522       0-2 years  Taught yourself a new language, framework, or ...
# 83134       0-2 years  Participated in a full-time developer training...
# 858         6-8 years  Taken an online course in programming or softw...
# 53284             NaN                                                NaN
# 37884       0-2 years  Received on-the-job training in software devel...
#
#                                          SelfTaughtTypes  \
# 17522  The official documentation and/or standards fo...
# 83134                                                NaN
# 858                                                  NaN
# 53284                                                NaN
# 37884  The official documentation and/or standards fo...
#
#                                       LanguageWorkedWith  Salary  \
# 17522                 C#;Java;Matlab;Python;SQL;HTML;CSS     510
# 83134                              JavaScript;TypeScript     120
# 858    C++;C#;Java;JavaScript;Matlab;SQL;HTML;Bash/Shell  100000
# 53284                                         C;PHP;HTML     NaN
# 37884  C;C++;C#;Java;JavaScript;Lua;PHP;Python;SQL;HT...     220
#
#                                   LanguageDesireNextYear  \
# 17522  C++;C#;Java;JavaScript;Objective-C;Perl;Python...
# 83134                              JavaScript;TypeScript
# 858                                                  NaN
# 53284                                           Python;R
# 37884  Assembly;C++;C#;Perl;Python;R;Ruby;Rust;Bash/S...
#
#                       FrameworkWorkedWith  \
# 17522                               Spark
# 83134               Angular;Node.js;React
# 858                               Angular
# 53284                                 NaN
# 37884  .NET Core;TensorFlow;Torch/PyTorch
#
#                                  FrameworkDesireNextYear OperatingSystem  \
# 17522  Angular;Django;Hadoop;Node.js;Spark;Spring;Ten...     Linux-based
# 83134                              Angular;Node.js;React         Windows
# 858                                                  NaN           MacOS
# 53284                                                NaN             NaN
# 37884                               .NET Core;TensorFlow     Linux-based
#
#                       Age  ConvertedSalary
# 17522   18 - 24 years old              NaN
# 83134   18 - 24 years old           1440.0
# 858     25 - 34 years old          14436.0
# 53284                 NaN              NaN
# 37884  Under 18 years old           3228.0

# %%
salaries_train.reset_index(inplace=True)

# %%
salaries_train.head()
# Out:
#    index         Country         Student                          Employment  \
# 0  17522          Greece              No                  Employed full-time
# 1  83134           Nepal  Yes, full-time  Not employed, but looking for work
# 2    858      Bangladesh              No                  Employed full-time
# 3  53284           India  Yes, full-time                  Employed full-time
# 4  37884  Czech Republic              No                  Employed part-time
#
#                                FormalEducation  \
# 0     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2  Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 3     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                    Primary/elementary school
#
#                                       UndergradMajor              CompanySize  \
# 0  Computer science, computer engineering, or sof...  Fewer than 10 employees
# 1                      Web development or web design                      NaN
# 2  Computer science, computer engineering, or sof...       10 to 19 employees
# 3  Computer science, computer engineering, or sof...  Fewer than 10 employees
# 4                                                NaN     100 to 499 employees
#
#                                              DevType YearsCoding  \
# 0  Back-end developer;Data or business analyst;Da...   3-5 years
# 1           Front-end developer;Full-stack developer   3-5 years
# 2  Back-end developer;Desktop or enterprise appli...   6-8 years
# 3                Back-end developer;Designer;Student   3-5 years
# 4  Back-end developer;Desktop or enterprise appli...   3-5 years
#
#   YearsCodingProf                                     EducationTypes  \
# 0       0-2 years  Taught yourself a new language, framework, or ...
# 1       0-2 years  Participated in a full-time developer training...
# 2       6-8 years  Taken an online course in programming or softw...
# 3             NaN                                                NaN
# 4       0-2 years  Received on-the-job training in software devel...
#
#                                      SelfTaughtTypes  \
# 0  The official documentation and/or standards fo...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  The official documentation and/or standards fo...
#
#                                   LanguageWorkedWith  Salary  \
# 0                 C#;Java;Matlab;Python;SQL;HTML;CSS     510
# 1                              JavaScript;TypeScript     120
# 2  C++;C#;Java;JavaScript;Matlab;SQL;HTML;Bash/Shell  100000
# 3                                         C;PHP;HTML     NaN
# 4  C;C++;C#;Java;JavaScript;Lua;PHP;Python;SQL;HT...     220
#
#                               LanguageDesireNextYear  \
# 0  C++;C#;Java;JavaScript;Objective-C;Perl;Python...
# 1                              JavaScript;TypeScript
# 2                                                NaN
# 3                                           Python;R
# 4  Assembly;C++;C#;Perl;Python;R;Ruby;Rust;Bash/S...
#
#                   FrameworkWorkedWith  \
# 0                               Spark
# 1               Angular;Node.js;React
# 2                             Angular
# 3                                 NaN
# 4  .NET Core;TensorFlow;Torch/PyTorch
#
#                              FrameworkDesireNextYear OperatingSystem  \
# 0  Angular;Django;Hadoop;Node.js;Spark;Spring;Ten...     Linux-based
# 1                              Angular;Node.js;React         Windows
# 2                                                NaN           MacOS
# 3                                                NaN             NaN
# 4                               .NET Core;TensorFlow     Linux-based
#
#                   Age  ConvertedSalary
# 0   18 - 24 years old              NaN
# 1   18 - 24 years old           1440.0
# 2   25 - 34 years old          14436.0
# 3                 NaN              NaN
# 4  Under 18 years old           3228.0

# %%
# Remove index col #
salaries_train.drop(["index"],axis=1,inplace=True)

# %%
salaries_train.head()
# Out:
#           Country         Student                          Employment  \
# 0          Greece              No                  Employed full-time
# 1           Nepal  Yes, full-time  Not employed, but looking for work
# 2      Bangladesh              No                  Employed full-time
# 3           India  Yes, full-time                  Employed full-time
# 4  Czech Republic              No                  Employed part-time
#
#                                FormalEducation  \
# 0     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2  Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 3     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                    Primary/elementary school
#
#                                       UndergradMajor              CompanySize  \
# 0  Computer science, computer engineering, or sof...  Fewer than 10 employees
# 1                      Web development or web design                      NaN
# 2  Computer science, computer engineering, or sof...       10 to 19 employees
# 3  Computer science, computer engineering, or sof...  Fewer than 10 employees
# 4                                                NaN     100 to 499 employees
#
#                                              DevType YearsCoding  \
# 0  Back-end developer;Data or business analyst;Da...   3-5 years
# 1           Front-end developer;Full-stack developer   3-5 years
# 2  Back-end developer;Desktop or enterprise appli...   6-8 years
# 3                Back-end developer;Designer;Student   3-5 years
# 4  Back-end developer;Desktop or enterprise appli...   3-5 years
#
#   YearsCodingProf                                     EducationTypes  \
# 0       0-2 years  Taught yourself a new language, framework, or ...
# 1       0-2 years  Participated in a full-time developer training...
# 2       6-8 years  Taken an online course in programming or softw...
# 3             NaN                                                NaN
# 4       0-2 years  Received on-the-job training in software devel...
#
#                                      SelfTaughtTypes  \
# 0  The official documentation and/or standards fo...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  The official documentation and/or standards fo...
#
#                                   LanguageWorkedWith  Salary  \
# 0                 C#;Java;Matlab;Python;SQL;HTML;CSS     510
# 1                              JavaScript;TypeScript     120
# 2  C++;C#;Java;JavaScript;Matlab;SQL;HTML;Bash/Shell  100000
# 3                                         C;PHP;HTML     NaN
# 4  C;C++;C#;Java;JavaScript;Lua;PHP;Python;SQL;HT...     220
#
#                               LanguageDesireNextYear  \
# 0  C++;C#;Java;JavaScript;Objective-C;Perl;Python...
# 1                              JavaScript;TypeScript
# 2                                                NaN
# 3                                           Python;R
# 4  Assembly;C++;C#;Perl;Python;R;Ruby;Rust;Bash/S...
#
#                   FrameworkWorkedWith  \
# 0                               Spark
# 1               Angular;Node.js;React
# 2                             Angular
# 3                                 NaN
# 4  .NET Core;TensorFlow;Torch/PyTorch
#
#                              FrameworkDesireNextYear OperatingSystem  \
# 0  Angular;Django;Hadoop;Node.js;Spark;Spring;Ten...     Linux-based
# 1                              Angular;Node.js;React         Windows
# 2                                                NaN           MacOS
# 3                                                NaN             NaN
# 4                               .NET Core;TensorFlow     Linux-based
#
#                   Age  ConvertedSalary
# 0   18 - 24 years old              NaN
# 1   18 - 24 years old           1440.0
# 2   25 - 34 years old          14436.0
# 3                 NaN              NaN
# 4  Under 18 years old           3228.0

# %% [markdown]
# **Dealing with Country col**

# %%
salaries_train.columns
# Out:
# Index(['Country', 'Student', 'Employment', 'FormalEducation', 'UndergradMajor',
#        'CompanySize', 'DevType', 'YearsCoding', 'YearsCodingProf',
#        'EducationTypes', 'SelfTaughtTypes', 'LanguageWorkedWith', 'Salary',
#        'LanguageDesireNextYear', 'FrameworkWorkedWith',
#        'FrameworkDesireNextYear', 'OperatingSystem', 'Age', 'ConvertedSalary'],
#       dtype='object')

# %%
salaries_train["Country"].unique()
# Out:
# array(['Greece', 'Nepal', 'Bangladesh', 'India', 'Czech Republic',
#        'Austria', 'Pakistan', 'United States', 'Germany', 'Australia',
#        'United Kingdom', 'Brazil', 'Bolivia', 'Indonesia', 'Switzerland',
#        'Poland', 'Sri Lanka', 'Canada', 'Sweden', 'Belarus', 'Bulgaria',
#        'Spain', 'France', 'Netherlands', 'Ghana', 'Russian Federation',
#        'Denmark', 'Mexico', 'Uruguay', 'Cuba', 'Luxembourg', 'Egypt',
#        'Italy', 'Hungary', 'Malaysia', 'Kuwait', 'Viet Nam', 'Turkey',
#        'Iran, Islamic Republic of...', 'Ireland', 'Colombia', 'Serbia',
#        'Jordan', 'Ukraine', 'Slovenia', 'Philippines', 'Portugal',
#        'Argentina', 'South Africa', 'Finland', 'Belgium', 'Iceland',
#        'Singapore', 'New Zealand', 'Romania', 'China'], dtype=object)

# %%
len(salaries_train["Country"].unique())
# Out:
# 56

# %% [markdown]
# **Dealing with the student col**

# %%
salaries_train["Student"].unique()
# Out:
# array(['No', 'Yes, full-time', 'Yes, part-time', nan], dtype=object)

# %% [markdown]
# replacing:
# - "Yes, full-time" --> "Yes"
# - "Yes, part-time" --> "Yes"
# - "nan" --> "No

# %%
salaries_train["Student"].replace("Yes, full-time","Yes",inplace=True)
salaries_train["Student"].replace("Yes, part-time","Yes",inplace=True)
salaries_train["Student"].replace(np.nan,"No",inplace=True)

# %%
# Show the distinct col values #
salaries_train["Student"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# **Dealing with the Employment col**

# %%
salaries_train["Employment"].unique()
# Out:
# array(['Employed full-time', 'Not employed, but looking for work',
#        'Employed part-time', 'Not employed, and not looking for work',
#        'Independent contractor, freelancer, or self-employed', nan],
#       dtype=object)

# %% [markdown]
# replace
# - 'Employed full-time' --> Employed
# - 'Employed part-time' --> Employed
# - 'Independent contractor, freelancer, or self-employed' --> Employed
# - 'Not employed, but looking for work' --> Not_employed
# - 'Not employed, and not looking for work' --> Not_employed
# - nan --> Not_employed

# %%
salaries_train["Employment"].replace(['Employed full-time','Employed part-time','Independent contractor, freelancer, or self-employed'],"Employed",inplace=True)
salaries_train["Employment"].replace(['Not employed, but looking for work','Not employed, and not looking for work',np.nan],"Not_employed",inplace=True)

# %%
salaries_train["Employment"].unique()
# Out:
# array(['Employed', 'Not_employed'], dtype=object)

# %% [markdown]
# **Dealing with the FormalEducation col**

# %%
salaries_train["FormalEducation"].unique()
# Out:
# array(['Bachelor’s degree (BA, BS, B.Eng., etc.)',
#        'Master’s degree (MA, MS, M.Eng., MBA, etc.)',
#        'Primary/elementary school',
#        'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
#        nan, 'Some college/university study without earning a degree',
#        'Associate degree', 'Professional degree (JD, MD, etc.)',
#        'Other doctoral degree (Ph.D, Ed.D., etc.)'], dtype=object)

# %% [markdown]
# we categorize the education into level:
# - High --> 'Master’s degree (MA, MS, M.Eng., MBA, etc.)','Other doctoral degree (Ph.D, Ed.D., etc.)'
# - Medium --> 'Bachelor’s degree (BA, BS, B.Eng., etc.)','Some college/university study without earning a degree','Associate degree', 'Professional degree (JD, MD, etc.)'
# - low --> 'Primary/elementary school','Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',nan

# %%
salaries_train["FormalEducation"].replace(['Master’s degree (MA, MS, M.Eng., MBA, etc.)','Other doctoral degree (Ph.D, Ed.D., etc.)'],"High",inplace=True)
salaries_train["FormalEducation"].replace(['Bachelor’s degree (BA, BS, B.Eng., etc.)','Some college/university study without earning a degree','Associate degree', 'Professional degree (JD, MD, etc.)'],"Medium",inplace=True)
salaries_train["FormalEducation"].replace(['Primary/elementary school','Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',np.nan],"Low",inplace=True)

# %%
salaries_train["FormalEducation"].unique()
# Out:
# array(['Medium', 'High', 'Low'], dtype=object)

# %% [markdown]
# **Dealing with UndergradMajor col**

# %%
salaries_train["UndergradMajor"].unique()
# Out:
# array(['Computer science, computer engineering, or software engineering',
#        'Web development or web design', nan,
#        'Information systems, information technology, or system administration',
#        'Another engineering discipline (ex. civil, electrical, mechanical)',
#        'A natural science (ex. biology, chemistry, physics)',
#        'A business discipline (ex. accounting, finance, marketing)',
#        'A health science (ex. nursing, pharmacy, radiology)',
#        'Mathematics or statistics',
#        'A humanities discipline (ex. literature, history, philosophy)',
#        'I never declared a major',
#        'A social science (ex. anthropology, psychology, political science)'],
#       dtype=object)

# %%
# Might drop this col later #

# %% [markdown]
# **Dealing with CompanySize col**

# %%
salaries_train[["Employment","CompanySize"]]
# Out:
#        Employment              CompanySize
# 0        Employed  Fewer than 10 employees
# 1    Not_employed                      NaN
# 2        Employed       10 to 19 employees
# 3        Employed  Fewer than 10 employees
# 4        Employed     100 to 499 employees
# ..            ...                      ...
# 195      Employed     100 to 499 employees
# 196      Employed                      NaN
# 197      Employed       20 to 99 employees
# 198      Employed     100 to 499 employees
# 199  Not_employed                      NaN
#
# [200 rows x 2 columns]

# %%
salaries_train[salaries_train["Employment"] == "Not_employed"]
# Out:
#                 Country Student    Employment FormalEducation  \
# 1                 Nepal     Yes  Not_employed          Medium
# 6              Pakistan      No  Not_employed             Low
# 16             Pakistan      No  Not_employed          Medium
# 18            Indonesia     Yes  Not_employed             Low
# 20                India     Yes  Not_employed          Medium
# 28           Bangladesh      No  Not_employed          Medium
# 32            Sri Lanka     Yes  Not_employed          Medium
# 38          Netherlands      No  Not_employed             Low
# 43          Netherlands     Yes  Not_employed          Medium
# 55        United States      No  Not_employed          Medium
# 58                Egypt      No  Not_employed          Medium
# 62                India      No  Not_employed          Medium
# 63   Russian Federation     Yes  Not_employed             Low
# 66                India     Yes  Not_employed          Medium
# 71               France      No  Not_employed             Low
# 79             Viet Nam      No  Not_employed             Low
# 81        United States     Yes  Not_employed          Medium
# 92              Germany     Yes  Not_employed             Low
# 97             Colombia     Yes  Not_employed             Low
# 114         Philippines      No  Not_employed          Medium
# 124               India     Yes  Not_employed          Medium
# 125       United States      No  Not_employed          Medium
# 131               India     Yes  Not_employed          Medium
# 133               India     Yes  Not_employed             Low
# 148       United States      No  Not_employed             Low
# 149       United States     Yes  Not_employed          Medium
# 156             Belgium      No  Not_employed             Low
# 158              France     Yes  Not_employed          Medium
# 163              Jordan     Yes  Not_employed             Low
# 168               India      No  Not_employed             Low
# 172         Philippines     Yes  Not_employed          Medium
# 175           Singapore     Yes  Not_employed             Low
# 176         New Zealand      No  Not_employed             Low
# 183       United States      No  Not_employed            High
# 185               China     Yes  Not_employed          Medium
# 186               India      No  Not_employed             Low
# 194       United States      No  Not_employed            High
# 199         Netherlands     Yes  Not_employed             Low
#
#                                         UndergradMajor CompanySize  \
# 1                        Web development or web design         NaN
# 6                                                  NaN         NaN
# 16   A business discipline (ex. accounting, finance...         NaN
# 18                                                 NaN         NaN
# 20   Another engineering discipline (ex. civil, ele...         NaN
# 28                       Web development or web design         NaN
# 32                       Web development or web design         NaN
# 38                                                 NaN         NaN
# 43                       Web development or web design         NaN
# 55   A humanities discipline (ex. literature, histo...         NaN
# 58                       Web development or web design         NaN
# 62                                                 NaN         NaN
# 63                                                 NaN         NaN
# 66   Computer science, computer engineering, or sof...         NaN
# 71                                                 NaN         NaN
# 79                                                 NaN         NaN
# 81   Computer science, computer engineering, or sof...         NaN
# 92                                                 NaN         NaN
# 97                                                 NaN         NaN
# 114  Information systems, information technology, o...         NaN
# 124                      Web development or web design         NaN
# 125  A social science (ex. anthropology, psychology...         NaN
# 131  Computer science, computer engineering, or sof...         NaN
# 133                                                NaN         NaN
# 148                                                NaN         NaN
# 149  A natural science (ex. biology, chemistry, phy...         NaN
# 156                                                NaN         NaN
# 158  Computer science, computer engineering, or sof...         NaN
# 163                                                NaN         NaN
# 168                                                NaN         NaN
# 172                      Web development or web design         NaN
# 175                                                NaN         NaN
# 176                                                NaN         NaN
# 183  A natural science (ex. biology, chemistry, phy...         NaN
# 185  Computer science, computer engineering, or sof...         NaN
# 186                                                NaN         NaN
# 194  Computer science, computer engineering, or sof...         NaN
# 199                                                NaN         NaN
#
#                                                DevType       YearsCoding  \
# 1             Front-end developer;Full-stack developer         3-5 years
# 6    Back-end developer;Desktop or enterprise appli...         3-5 years
# 16   Back-end developer;C-suite executive (CEO, CTO...         3-5 years
# 18   Back-end developer;C-suite executive (CEO, CTO...         3-5 years
# 20                                             Student         0-2 years
# 28                                  Back-end developer         0-2 years
# 32                Designer;Front-end developer;Student         0-2 years
# 38                                                 NaN               NaN
# 43   Back-end developer;Front-end developer;Marketi...         3-5 years
# 55    Front-end developer;Full-stack developer;Student         0-2 years
# 58   Back-end developer;Designer;Full-stack develop...         0-2 years
# 62                                                 NaN         0-2 years
# 63   Back-end developer;Desktop or enterprise appli...         3-5 years
# 66                                             Student         3-5 years
# 71    Front-end developer;Student;System administrator         0-2 years
# 79                                                 NaN               NaN
# 81   Educator or academic researcher;Front-end deve...         6-8 years
# 92                                             Student         3-5 years
# 97   Back-end developer;Desktop or enterprise appli...         0-2 years
# 114  Back-end developer;DevOps specialist;Full-stac...         6-8 years
# 124             DevOps specialist;Full-stack developer         0-2 years
# 125                    Marketing or sales professional         0-2 years
# 131                                                NaN         3-5 years
# 133                        Front-end developer;Student         0-2 years
# 148                 Game or graphics developer;Student         3-5 years
# 149  Back-end developer;Designer;Front-end develope...         3-5 years
# 156                                                NaN               NaN
# 158  Data scientist or machine learning specialist;...         6-8 years
# 163                                                NaN               NaN
# 168                                                NaN               NaN
# 172  Back-end developer;Data or business analyst;Da...         3-5 years
# 175  Back-end developer;Database administrator;Student         3-5 years
# 176  Back-end developer;Desktop or enterprise appli...         0-2 years
# 183  Data or business analyst;Data scientist or mac...       24-26 years
# 185  Data scientist or machine learning specialist;...         3-5 years
# 186                                            Student         0-2 years
# 194  Back-end developer;Desktop or enterprise appli...  30 or more years
# 199  Back-end developer;Data scientist or machine l...         6-8 years
#
#       YearsCodingProf                                     EducationTypes  \
# 1           0-2 years  Participated in a full-time developer training...
# 6           0-2 years  Taken an online course in programming or softw...
# 16          3-5 years  Taken an online course in programming or softw...
# 18   30 or more years                                                NaN
# 20                NaN                                                NaN
# 28                NaN                        Participated in a hackathon
# 32          0-2 years  Taken an online course in programming or softw...
# 38                NaN                                                NaN
# 43          0-2 years                                                NaN
# 55          0-2 years  Taken an online course in programming or softw...
# 58                NaN                                                NaN
# 62                NaN                                                NaN
# 63          0-2 years  Taught yourself a new language, framework, or ...
# 66                NaN  Taken an online course in programming or softw...
# 71          0-2 years  Taken an online course in programming or softw...
# 79                NaN                                                NaN
# 81          0-2 years  Received on-the-job training in software devel...
# 92                NaN  Taught yourself a new language, framework, or ...
# 97          0-2 years  Taken an online course in programming or softw...
# 114               NaN                                                NaN
# 124         0-2 years  Taken an online course in programming or softw...
# 125               NaN  Taken an online course in programming or softw...
# 131               NaN                                                NaN
# 133         0-2 years                                                NaN
# 148         0-2 years  Taught yourself a new language, framework, or ...
# 149         0-2 years  Taken an online course in programming or softw...
# 156               NaN                                                NaN
# 158               NaN                                                NaN
# 163               NaN                                                NaN
# 168               NaN                                                NaN
# 172               NaN                                                NaN
# 175         0-2 years  Taken an online course in programming or softw...
# 176         0-2 years  Taught yourself a new language, framework, or ...
# 183       24-26 years  Taken an online course in programming or softw...
# 185               NaN                                                NaN
# 186               NaN  Taken an online course in programming or softw...
# 194       27-29 years  Received on-the-job training in software devel...
# 199         0-2 years  Taken an online course in programming or softw...
#
#                                        SelfTaughtTypes  \
# 1                                                  NaN
# 6                                                  NaN
# 16   Questions & answers on Stack Overflow;Online d...
# 18                                                 NaN
# 20                                                 NaN
# 28                                                 NaN
# 32                                                 NaN
# 38                                                 NaN
# 43                                                 NaN
# 55   The official documentation and/or standards fo...
# 58                                                 NaN
# 62                                                 NaN
# 63   The official documentation and/or standards fo...
# 66                                                 NaN
# 71   The official documentation and/or standards fo...
# 79                                                 NaN
# 81   The official documentation and/or standards fo...
# 92   The official documentation and/or standards fo...
# 97   The official documentation and/or standards fo...
# 114                                                NaN
# 124  The official documentation and/or standards fo...
# 125  A college/university computer science or softw...
# 131                                                NaN
# 133                                                NaN
# 148  The official documentation and/or standards fo...
# 149  The official documentation and/or standards fo...
# 156                                                NaN
# 158                                                NaN
# 163                                                NaN
# 168                                                NaN
# 172                                                NaN
# 175  The official documentation and/or standards fo...
# 176  The official documentation and/or standards fo...
# 183  The official documentation and/or standards fo...
# 185                                                NaN
# 186  The official documentation and/or standards fo...
# 194  The official documentation and/or standards fo...
# 199  The official documentation and/or standards fo...
#
#                                     LanguageWorkedWith       Salary  \
# 1                                JavaScript;TypeScript          120
# 6                                 Java;Python;HTML;CSS          NaN
# 16                  Lua;Python;SQL;HTML;CSS;Bash/Shell          NaN
# 18   Assembly;C;C++;C#;CoffeeScript;Clojure;Erlang;...  08217000063
# 20                                                 NaN          NaN
# 28                    Assembly;JavaScript;PHP;HTML;CSS          NaN
# 32                                 JavaScript;HTML;CSS          250
# 38                                                 NaN          NaN
# 43                                                 NaN          NaN
# 55                             JavaScript;SQL;HTML;CSS            0
# 58                                            HTML;CSS          NaN
# 62                                                 NaN          NaN
# 63                                                 NaN          NaN
# 66                C;C++;JavaScript;HTML;CSS;Bash/Shell          NaN
# 71         Haskell;JavaScript;Rust;HTML;CSS;Bash/Shell          NaN
# 79                                                 NaN          NaN
# 81          C++;C#;Java;JavaScript;Python;SQL;HTML;CSS          NaN
# 92                      C++;Java;JavaScript;PHP;Python          NaN
# 97   Java;JavaScript;PHP;Python;SQL;HTML;CSS;Bash/S...          NaN
# 114                                                NaN          NaN
# 124                          C;C++;HTML;CSS;Bash/Shell          NaN
# 125                                           HTML;CSS        35000
# 131                                                NaN          NaN
# 133                                                NaN          NaN
# 148                                             Python          NaN
# 149  Assembly;C++;Groovy;Java;JavaScript;Python;SQL...          NaN
# 156                                                NaN          NaN
# 158                                                NaN          NaN
# 163                                                NaN          NaN
# 168                                                NaN          NaN
# 172                   C;JavaScript;PHP;Python;HTML;CSS          NaN
# 175  C++;JavaScript;Objective-C;PHP;SQL;Swift;HTML;CSS          NaN
# 176   C++;C#;Go;Java;JavaScript;Lua;Objective-C;Python          NaN
# 183                        JavaScript;Python;Scala;SQL          NaN
# 185  C;C++;JavaScript;Matlab;Python;HTML;CSS;Bash/S...          NaN
# 186                                                NaN          NaN
# 194              JavaScript;Python;HTML;CSS;Bash/Shell            0
# 199                                         C#;PHP;SQL          NaN
#
#                                 LanguageDesireNextYear  \
# 1                                JavaScript;TypeScript
# 6    Assembly;C#;Java;JavaScript;Perl;Python;Ruby;H...
# 16                                     Python;HTML;CSS
# 18   Assembly;C;C++;C#;CoffeeScript;Clojure;Erlang;...
# 20                                                 NaN
# 28                                                 PHP
# 32                                 JavaScript;HTML;CSS
# 38                                                 NaN
# 43                                                 NaN
# 55   Java;JavaScript;PHP;Python;Scala;SQL;HTML;CSS;...
# 58                      JavaScript;PHP;Python;HTML;CSS
# 62                            C;C#;JavaScript;SQL;HTML
# 63                                    C#;Go;JavaScript
# 66   CoffeeScript;JavaScript;Python;HTML;CSS;Bash/S...
# 71                                   Assembly;C;Kotlin
# 79                                                 NaN
# 81                                     C++;Java;Python
# 92                                            C;C++;Go
# 97                            Assembly;C;C++;Go;Kotlin
# 114                                                NaN
# 124                 C++;JavaScript;HTML;CSS;Bash/Shell
# 125                     JavaScript;Python;SQL;HTML;CSS
# 131                                                NaN
# 133                                                NaN
# 148                                             Python
# 149    C#;Groovy;JavaScript;Python;SQL;TypeScript;HTML
# 156                                                NaN
# 158                                                NaN
# 163                                                NaN
# 168                                                NaN
# 172                C++;C#;Java;R;VB.NET;Visual Basic 6
# 175                                          Java;Ruby
# 176  Assembly;C++;CoffeeScript;Clojure;Go;JavaScrip...
# 183                        JavaScript;Python;Scala;SQL
# 185                                C;C++;Matlab;Python
# 186  Assembly;C;C++;C#;CoffeeScript;Clojure;Erlang;...
# 194  Go;Haskell;JavaScript;Rust;TypeScript;Kotlin;O...
# 199                       C#;Haskell;Python;Bash/Shell
#
#                                    FrameworkWorkedWith  \
# 1                                Angular;Node.js;React
# 6                                                  NaN
# 16                                              Django
# 18   Angular;.NET Core;Django;Hadoop;Node.js;React;...
# 20                                                 NaN
# 28                                                 NaN
# 32                                             Angular
# 38                                                 NaN
# 43                                                 NaN
# 55                               Angular;Node.js;React
# 58                                                 NaN
# 62                                                 NaN
# 63                                           .NET Core
# 66                                                 NaN
# 71                                             Node.js
# 79                                                 NaN
# 81                                               React
# 92                                                 NaN
# 97                                Django;Node.js;React
# 114                                                NaN
# 124                                                NaN
# 125                                                NaN
# 131                                                NaN
# 133                                                NaN
# 148                                                NaN
# 149                                    Angular;Node.js
# 156                                                NaN
# 158                                                NaN
# 163                                                NaN
# 168                                                NaN
# 172                                                NaN
# 175                                                NaN
# 176                                            Node.js
# 183                  Django;Hadoop;Node.js;React;Spark
# 185                                 Node.js;TensorFlow
# 186                                                NaN
# 194                                      Node.js;React
# 199                                                NaN
#
#                                FrameworkDesireNextYear OperatingSystem  \
# 1                                Angular;Node.js;React         Windows
# 6                   Django;Node.js;React;Torch/PyTorch         Windows
# 16                                   Django;TensorFlow     Linux-based
# 18   Angular;.NET Core;Django;Hadoop;Node.js;React;...             NaN
# 20                                                 NaN             NaN
# 28                                                 NaN             NaN
# 32                                             Angular         Windows
# 38                                                 NaN             NaN
# 43                                                 NaN             NaN
# 55                                       Node.js;React           MacOS
# 58                        Angular;Django;Node.js;React         Windows
# 62                                   Angular;.NET Core         Windows
# 63                                           .NET Core         Windows
# 66                               Angular;Node.js;React     Linux-based
# 71                      React;TensorFlow;Torch/PyTorch     Linux-based
# 79                                                 NaN             NaN
# 81                                               React         Windows
# 92                                                 NaN     Linux-based
# 97                        Angular;Django;Node.js;React         Windows
# 114                                                NaN             NaN
# 124                       Angular;Django;Node.js;React     Linux-based
# 125                     .NET Core;Django;Node.js;React         Windows
# 131                                                NaN             NaN
# 133                                                NaN             NaN
# 148                                                NaN           MacOS
# 149                      Angular;Django;Node.js;Spring         Windows
# 156                                                NaN             NaN
# 158                                                NaN             NaN
# 163                                                NaN             NaN
# 168                                                NaN             NaN
# 172                                                NaN             NaN
# 175                                            Node.js           MacOS
# 176                   Node.js;React;Xamarin;TensorFlow         Windows
# 183              Django;Node.js;React;Spark;TensorFlow     Linux-based
# 185                           TensorFlow;Torch/PyTorch     Linux-based
# 186                                                NaN         Windows
# 194                           Node.js;React;TensorFlow         Windows
# 199                                                NaN         Windows
#
#                     Age  ConvertedSalary
# 1     18 - 24 years old           1440.0
# 6    Under 18 years old              NaN
# 16    35 - 44 years old              NaN
# 18    35 - 44 years old        1000000.0
# 20                  NaN              NaN
# 28                  NaN              NaN
# 32    18 - 24 years old           3000.0
# 38                  NaN              NaN
# 43                  NaN              NaN
# 55    18 - 24 years old              0.0
# 58                  NaN              NaN
# 62                  NaN              NaN
# 63    18 - 24 years old              NaN
# 66    18 - 24 years old              NaN
# 71   Under 18 years old              NaN
# 79                  NaN              NaN
# 81    18 - 24 years old              NaN
# 92    18 - 24 years old              NaN
# 97   Under 18 years old              NaN
# 114                 NaN              NaN
# 124   18 - 24 years old              NaN
# 125   25 - 34 years old          35000.0
# 131                 NaN              NaN
# 133                 NaN              NaN
# 148  Under 18 years old              NaN
# 149   18 - 24 years old              NaN
# 156                 NaN              NaN
# 158                 NaN              NaN
# 163                 NaN              NaN
# 168                 NaN              NaN
# 172                 NaN              NaN
# 175  Under 18 years old              NaN
# 176  Under 18 years old              NaN
# 183   55 - 64 years old              NaN
# 185                 NaN              NaN
# 186  Under 18 years old              NaN
# 194   45 - 54 years old              0.0
# 199   18 - 24 years old              NaN

# %% [markdown]
# The idea is:
#
# if salaries_train["Employment"] == "Not_employed" --> salaries_train["CompanySize"] == np.nan:
#
#     then set salaries_train["CompanySize"] --> 0

# %%
# To be updated later #
# salaries_train[salaries_train["Employment"] == "Not_employed"][["CompanySize"]].replace(np.nan,0,inplace=True)

# %%
salaries_train["CompanySize"].unique()
# Out:
# array(['Fewer than 10 employees', nan, '10 to 19 employees',
#        '100 to 499 employees', '20 to 99 employees',
#        '500 to 999 employees', '1,000 to 4,999 employees',
#        '5,000 to 9,999 employees', '10,000 or more employees'],
#       dtype=object)

# %% [markdown]
# categorize by average:
#
# - 'Fewer than 10 employees' --> 10
# - '10 to 19 employees' --> 15
# - '20 to 99 employees' --> 60
# - '100 to 499 employees' --> 300
# - '500 to 999 employees' --> 750
# - '1,000 to 4,999 employees' --> 3000
# - '5,000 to 9,999 employees' --> 7500
# - '10,000 or more employees' --> 10000

# %%
salaries_train["CompanySize"].replace('Fewer than 10 employees',10,inplace=True)
salaries_train["CompanySize"].replace('10 to 19 employees',15,inplace=True)
salaries_train["CompanySize"].replace('20 to 99 employees',60,inplace=True)
salaries_train["CompanySize"].replace('100 to 499 employees',300,inplace=True)
salaries_train["CompanySize"].replace('500 to 999 employees',750,inplace=True)
salaries_train["CompanySize"].replace('1,000 to 4,999 employees',3000,inplace=True)
salaries_train["CompanySize"].replace('5,000 to 9,999 employees',7500,inplace=True)
salaries_train["CompanySize"].replace('10,000 or more employees',10000,inplace=True)

# %%
salaries_train.head()
# Out:
#           Country Student    Employment FormalEducation  \
# 0          Greece      No      Employed          Medium
# 1           Nepal     Yes  Not_employed          Medium
# 2      Bangladesh      No      Employed            High
# 3           India     Yes      Employed          Medium
# 4  Czech Republic      No      Employed             Low
#
#                                       UndergradMajor  CompanySize  \
# 0  Computer science, computer engineering, or sof...         10.0
# 1                      Web development or web design          NaN
# 2  Computer science, computer engineering, or sof...         15.0
# 3  Computer science, computer engineering, or sof...         10.0
# 4                                                NaN        300.0
#
#                                              DevType YearsCoding  \
# 0  Back-end developer;Data or business analyst;Da...   3-5 years
# 1           Front-end developer;Full-stack developer   3-5 years
# 2  Back-end developer;Desktop or enterprise appli...   6-8 years
# 3                Back-end developer;Designer;Student   3-5 years
# 4  Back-end developer;Desktop or enterprise appli...   3-5 years
#
#   YearsCodingProf                                     EducationTypes  \
# 0       0-2 years  Taught yourself a new language, framework, or ...
# 1       0-2 years  Participated in a full-time developer training...
# 2       6-8 years  Taken an online course in programming or softw...
# 3             NaN                                                NaN
# 4       0-2 years  Received on-the-job training in software devel...
#
#                                      SelfTaughtTypes  \
# 0  The official documentation and/or standards fo...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  The official documentation and/or standards fo...
#
#                                   LanguageWorkedWith  Salary  \
# 0                 C#;Java;Matlab;Python;SQL;HTML;CSS     510
# 1                              JavaScript;TypeScript     120
# 2  C++;C#;Java;JavaScript;Matlab;SQL;HTML;Bash/Shell  100000
# 3                                         C;PHP;HTML     NaN
# 4  C;C++;C#;Java;JavaScript;Lua;PHP;Python;SQL;HT...     220
#
#                               LanguageDesireNextYear  \
# 0  C++;C#;Java;JavaScript;Objective-C;Perl;Python...
# 1                              JavaScript;TypeScript
# 2                                                NaN
# 3                                           Python;R
# 4  Assembly;C++;C#;Perl;Python;R;Ruby;Rust;Bash/S...
#
#                   FrameworkWorkedWith  \
# 0                               Spark
# 1               Angular;Node.js;React
# 2                             Angular
# 3                                 NaN
# 4  .NET Core;TensorFlow;Torch/PyTorch
#
#                              FrameworkDesireNextYear OperatingSystem  \
# 0  Angular;Django;Hadoop;Node.js;Spark;Spring;Ten...     Linux-based
# 1                              Angular;Node.js;React         Windows
# 2                                                NaN           MacOS
# 3                                                NaN             NaN
# 4                               .NET Core;TensorFlow     Linux-based
#
#                   Age  ConvertedSalary
# 0   18 - 24 years old              NaN
# 1   18 - 24 years old           1440.0
# 2   25 - 34 years old          14436.0
# 3                 NaN              NaN
# 4  Under 18 years old           3228.0

# %%
salaries_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  200 non-null    object
#  1   Student                  200 non-null    object
#  2   Employment               200 non-null    object
#  3   FormalEducation          200 non-null    object
#  4   UndergradMajor           161 non-null    object
#  5   CompanySize              136 non-null    float64
#  6   DevType                  187 non-null    object
#  7   YearsCoding              192 non-null    object
#  8   YearsCodingProf          153 non-null    object
#  9   EducationTypes           142 non-null    object
#  10  SelfTaughtTypes          122 non-null    object
#  11  LanguageWorkedWith       162 non-null    object
#  12  Salary                   95 non-null     object
#  13  LanguageDesireNextYear   150 non-null    object
#  14  FrameworkWorkedWith      116 non-null    object
#  15  FrameworkDesireNextYear  125 non-null    object
#  16  OperatingSystem          161 non-null    object
#  17  Age                      137 non-null    object
#  18  ConvertedSalary          89 non-null     float64
# dtypes: float64(2), object(17)
# memory usage: 29.8+ KB

# %%
# will deal with the null  #
